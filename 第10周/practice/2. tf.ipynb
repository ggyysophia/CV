# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# pip install yapf

# %%
# 加载数据   #
x_data = np.linspace(-0.5, 0.5, 200)[:, np.newaxis]  # (200,1)
noise = np.random.normal(0, 0.02, x_data.shape)
y_data = x_data ** 3 + noise

# 定义两个placeholder存放输入数据
x = tf.placeholder(tf.float32, [None, 1])
y = tf.placeholder(tf.float32, [None, 1])

# 定义神经网络的中间层
Weight_L1 = tf.Variable(tf.random_normal([1, 10]))
biases_L1 = tf.Variable(tf.zeros([1, 10]))
Wx_plus_b_L1 = tf.matmul(x, Weight_L1) + biases_L1
L1 = tf.nn.tanh(Wx_plus_b_L1)

# 定义神经网络输出层
Weight_L2 = tf.Variable(tf.random_normal([10, 1]))
biases_L2 = tf.Variable(tf.zeros([1, 1]))
Wx_plus_b_L2 = tf.matmul(L1, Weight_L2) + biases_L2
prediction = tf.nn.tanh(Wx_plus_b_L2)

# 定义损失函数（均方差函数）
loss = tf.reduce_mean(tf.square(y - prediction))
# 定义方向传播算法（使用梯度下降算法训练） # learning_rate = 0.1
train_step = tf.train.GradientDescentOptimizer(0.1).minimize(loss)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    # the times of training data
    for i in range(5000):
        sess.run(train_step, feed_dict={x: x_data, y: y_data})
        
    # 获得预测值
    prediction_values = sess.run(prediction, feed_dict={x:x_data})
    
    #plot
    plt.figure()
    plt.scatter(x_data, y_data)  # real
    plt.plot(x_data, prediction_values, 'r-', lw=5)
    plt.show()

# %%
x_data_x = np.linspace(0, 3, 300)[:, np.newaxis]
noise = np.random.normal(0, 1, x_data_x.shape)
y_data_y = x_data_x ** 2 + x_data_x + noise

x = tf.placeholder(tf.float32, [None, 1])
y = tf.placeholder(tf.float32, [None, 1])

Weight_L1 = tf.Variable(tf.random_normal([1, 12]))
biases_L1 = tf.Variable(tf.zeros([1, 12]))
Wx_plus_b_L1 = tf.matmul(x, Weight_L1) + biases_L1
L1 = tf.nn.tanh(Wx_plus_b_L1)

Weight_L2 = tf.Variable(tf.random_normal([12, 1]))
biases_L2 = tf.Variable(tf.zeros([1, 1]))
Wx_plus_b_L2 = tf.matmul(L1, Weight_L2) + biases_L2
prediction = tf.nn.tanh(Wx_plus_b_L2)

# loss, 梯度下降算法
loss = tf.reduce_mean(tf.square(y - prediction))
train_step = tf.train.GradientDescentOptimizer(0.1).minimize(loss)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(2000):
        sess.run(train_step, feed_dict={x:x_data_x, y:y_data_y})
        
    prediction_values = sess.run(prediction, )

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
 
x_data1=np.linspace(-0.5,0.5,200)[:,np.newaxis]
noise=np.random.normal(0,0.02,x_data.shape)
y_data1=np.square(x_data)+noise + x_data1 ** 3

x = tf.placeholder(tf.float32, [None, 1])
y = tf.placeholder(tf.float32, [None, 1])
 
Weight_L1 = tf.Variable(tf.random_normal([1, 12]))
biases_L1 = tf.Variable(tf.zeros([1, 12]))
Wx_plus_b_L1 = tf.matmul(x, Weight_L1) + biases_L1
L1 = tf.nn.tanh(Wx_plus_b_L1)

Weight_L2 = tf.Variable(tf.random_normal([12, 1]))
biases_L2 = tf.Variable(tf.zeros([1, 1]))
Wx_plus_b_L2 = tf.matmul(L1, Weight_L2) + biases_L2
prediction = tf.nn.tanh(Wx_plus_b_L2)

# loss, 梯度下降算法
loss = tf.reduce_mean(tf.square(y - prediction))
train_step = tf.train.GradientDescentOptimizer(0.1).minimize(loss)
 
with tf.Session() as sess:
    #变量初始化
    sess.run(tf.global_variables_initializer())
    #训练2000次
    for i in range(2000):
        sess.run(train_step,feed_dict={x:x_data1,y:y_data1})
 
    #获得预测值
    prediction_value=sess.run(prediction,feed_dict={x:x_data1})
 
    #画图
    plt.figure()
    plt.scatter(x_data1,y_data1)   #散点是真实值
    plt.plot(x_data1,prediction_value,'r-',lw=5)   #曲线是预测值
    plt.show()
